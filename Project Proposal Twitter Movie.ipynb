# %% [markdown]
# # Goals

# %% [markdown]
# **What is the topic of your project**
#
# - Using twint to collect and NLP show the sentiment of twitter users about movies
#
# **What is the business or social case of the project?**
#
# - Classify the success of a movie by predicting ratings using twitter sentiment
#
# **Why does it matter?**
#
# - a movie that is rated better might make more money because more people will want to see it
# - twitter sentiment after trailer, if it's bad and social media continuously comments on something they're upset about a team needs to come in and fix the issue (ex Sonic)

# %% [markdown]
# # Data

# %%
import twint
import nest_asyncio

nest_asyncio.apply()

# %%
c = twint.Config()
c.Search = "Frozen"
c.Limit = 20

# Run
twint.run.Search(c)
# Out:
# 1354075924111765514 2021-01-26 09:37:12 -0500 <jancro17> mira quedé frozen como elsa. que manera de empezar esta reunión 😟
# 1354075917895790597 2021-01-26 09:37:10 -0500 <frozen838> 연말정산 하지는 않고 해야된다는 말만 하면서 순식간에 늙어가고 잇음
# 1354075896823607296 2021-01-26 09:37:05 -0500 <frozen_ornot> 헐....이분 음색 완전 의외야
# 1354075894558691331 2021-01-26 09:37:05 -0500 <frozen_kinugasa> 箱とかあるんだね プレバンがネックレスにして売ってる
# 1354075863818661893 2021-01-26 09:36:58 -0500 <SaiDosapa> #ITBP personnel on 26 January, celebrated the 72nd #RepublicDay at a high-altitude border outpost in #Ladakh. Braving minus 25° Celsius, the jawans marched with the Tricolour flag on a frozen water body at 17,000 feet.  https://t.co/0OBCf2XqnQ
# 1354075834588520453 2021-01-26 09:36:51 -0500 <cicimurray> THE FIELD IS FROZEN YALL IM NOT GONNA MAKE IT😭
# 1354075808894246912 2021-01-26 09:36:45 -0500 <koogIossy> in the frozen y break the wall  @hf_dreamcatcher #드림캐쳐 #Dreamcatcher
# ...

# %%
c = twint.Config()
# c.Username = "Movie"
c.Search = "Inception"
c.Limit = 5000
c.Since = "2010-04-01"
c.Until = "2011-01-29"

# Run
twint.run.Search(c)
# Out:
# 30776953027956739 2011-01-27 18:59:32 -0500 <EmilyNMurray> Watching inception. Joseph gordon-levitt. Oh yeah :)
# 30776922921246720 2011-01-27 18:59:24 -0500 <LisaAsanuma> Ken Watanabe &lt;---Reason to see Inception more than once. (See also: Tom Hardy)
# 30776462000791552 2011-01-27 18:57:34 -0500 <MsAllurer> #NW Inception! yh yh yh.. stale girl.. waheva.. According to ibo proverb translated to english "The older the wine, the sweeter the taste"
# 30776412738682880 2011-01-27 18:57:23 -0500 <AlexaChill> 'Black Swan', 'The Social Network', 'Inception' si 'Eat Pray Love 'recuperate si bifate . Another suggestions?
# 30776381751173121 2011-01-27 18:57:15 -0500 <MarioCayetano> I just voted for Inception for #BestScreenplay on Oscar.com via @TheAcademy.  http://soc.li/MiotdtD
# 30776214385860608 2011-01-27 18:56:35 -0500 <forrestfire101> @spastikchuwawa +Inception soundtrack
# ...

# %% [markdown]
# **What is the minimum number of rows?**
#
# - date row
# - actual message
# - user
# - NLP label: 1 positive tone, 0 neutral tone, -1 negative tone
# - retweets
# - liked tweet

# %% [markdown]
# # Visualization

# %% [markdown]
# **How will you visualizes features?**
#
# - bar graph of different words
#
# **How will you produce at least 4 visualizations**
#
# - words combined in a bar graph (after movie trailer)
# - each movie will have it's own bar graph
# - kmeans seperation - 3 clusters, hit neutral and bad

# %% [markdown]
# # Tech Stack

# %% [markdown]
# **What technologies will you use?**
#
# - twint
# - time series
# - NLP
# - linear regression to make predictions
# - random forest
# - kmeans clustering
# - SVM
# - confusion matrix
# - grid search :(

# %% [markdown]
# # Research and Domain Knowledge

# %% [markdown]
# - I've watched movies before. I know how to rate things good or bad.
# - I have to research movie release dates or trailer release dates
# - The pandemic probably affected movies

# %% [markdown]
# # MVP & Supervised Learning

# %% [markdown]
# - an NLP project
# - 10 movies
# - using twitter sentiment to predict movie ratings
# - simple regression models

# %% [markdown]
# # Beyond the MVP

# %% [markdown]
# **How will you build on your MVP to improve and add to your project? What are your stretch goals?**
#
# - a larger dataset (more movies and more tweets per movie)
# - deep learning (neural network)

# %% [markdown]
# # Evaluation Metrics

# %% [markdown]
# - word count
